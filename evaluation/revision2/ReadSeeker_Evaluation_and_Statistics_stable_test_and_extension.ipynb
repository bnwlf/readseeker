# %% [markdown]
# # Readseeker Evaluation Notebook
# *Revison 2*
#
# by Ben Wulf @ HTW Berlin - University of Applied Sciences

# %% [markdown]
# ## Import Dependencies

# %%
import pandas
import seaborn as sns
from tqdm.notebook import tqdm
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
import pandas as pd
import gzip
import os

from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Load Readseeker Data

# %%
readseeker_result_filename = "../benchmark_result/dnabertCDS_classification_benchmark_11Samples_6References.tsv"
readseeker_result = pandas.read_csv(readseeker_result_filename,sep ="\t",lineterminator='\n',index_col=None)

rs_r_f2 = "../benchmark_result/dnabertCDS_classification_benchmark_injected_1Samples_1References.tsv"
rs_r2 = pandas.read_csv(rs_r_f2,sep ="\t",lineterminator='\n',index_col=None)

readseeker_result = pd.concat([readseeker_result, rs_r2], axis=0)

# HotFix for LTS and Language Issues
readseeker_result.rename(columns={"Referenz": "Reference"},inplace=True)
if "ReadNotInBlastHits" in readseeker_result:
    readseeker_result.drop(['ReadNotInBlastHits'], axis=1,inplace=True)
readseeker_result
# Out:
#        Label                                               Name  \
# 0          1                               SRR22674487.819286_2
# 1          1                               SRR22674487.287945_2
# 2          1                                SRR22674487.58161_2
# 3          1                               SRR22674487.371638_2
# 4          1                               SRR22674487.956120_2
# ...      ...                                                ...
# 24995      0  /home/bwulf/.genomic_benchmarks/demo_coding_vs...
# 24996      0  /home/bwulf/.genomic_benchmarks/demo_coding_vs...
# 24997      0  /home/bwulf/.genomic_benchmarks/demo_coding_vs...
# 24998      0  /home/bwulf/.genomic_benchmarks/demo_coding_vs...
# 24999      0  /home/bwulf/.genomic_benchmarks/demo_coding_vs...
#
#        MappingQuality Reference                                 Sample  \
# 0                  42     ecoli                            SRR22674487
# 1                  42     ecoli                            SRR22674487
# 2                  42     ecoli                            SRR22674487
# 3                  42     ecoli                            SRR22674487
# 4                  42     ecoli                            SRR22674487
# ...               ...       ...                                    ...
# 24995               0  human_bm  demo_coding_vs_intergenomic_seqs_test
# 24996               0  human_bm  demo_coding_vs_intergenomic_seqs_test
# 24997               0  human_bm  demo_coding_vs_intergenomic_seqs_test
# 24998               0  human_bm  demo_coding_vs_intergenomic_seqs_test
# 24999               0  human_bm  demo_coding_vs_intergenomic_seqs_test
#
#        Prediction
# 0        0.965642
# 1        0.998971
# 2        0.998492
# 3        0.972361
# 4        0.998891
# ...           ...
# 24995    0.000317
# 24996    0.000395
# 24997    0.001849
# 24998    0.000369
# 24999    0.013915
#
# [1704026 rows x 6 columns]

# %% [markdown]
# ## Rename references to scientific names

# %%
renameSamples = {
    
    "ecoli":"Escherichia coli",
    "human":"Human",
    "gammaherpes4":"Epstein-Barr Virus",
    "sars2":"SARS-CoV-2",
    "mycobacteriumtubercolosis":"Mycobacterium tuberculosis",
    "mouse": "Mus musculus",
    "human_bm": "Genomic Benchmark (Human)"
}

readseeker_result.replace({"Reference":renameSamples},inplace=True)
display(readseeker_result)
#readseeker_result = readseeker_result.loc[:("Reference")].replace(renameSamples)
# Out:
#        Label                                               Name  \
# 0          1                               SRR22674487.819286_2
# 1          1                               SRR22674487.287945_2
# 2          1                                SRR22674487.58161_2
# 3          1                               SRR22674487.371638_2
# 4          1                               SRR22674487.956120_2
# ...      ...                                                ...
# 24995      0  /home/bwulf/.genomic_benchmarks/demo_coding_vs...
# 24996      0  /home/bwulf/.genomic_benchmarks/demo_coding_vs...
# 24997      0  /home/bwulf/.genomic_benchmarks/demo_coding_vs...
# 24998      0  /home/bwulf/.genomic_benchmarks/demo_coding_vs...
# 24999      0  /home/bwulf/.genomic_benchmarks/demo_coding_vs...
#
#        MappingQuality                  Reference  \
# 0                  42           Escherichia coli
# 1                  42           Escherichia coli
# 2                  42           Escherichia coli
# 3                  42           Escherichia coli
# 4                  42           Escherichia coli
# ...               ...                        ...
# 24995               0  Genomic Benchmark (Human)
# 24996               0  Genomic Benchmark (Human)
# 24997               0  Genomic Benchmark (Human)
# 24998               0  Genomic Benchmark (Human)
# 24999               0  Genomic Benchmark (Human)
#
#                                       Sample  Prediction
# 0                                SRR22674487    0.965642
# 1                                SRR22674487    0.998971
# 2                                SRR22674487    0.998492
# 3                                SRR22674487    0.972361
# 4                                SRR22674487    0.998891
# ...                                      ...         ...
# 24995  demo_coding_vs_intergenomic_seqs_test    0.000317
# 24996  demo_coding_vs_intergenomic_seqs_test    0.000395
# 24997  demo_coding_vs_intergenomic_seqs_test    0.001849
# 24998  demo_coding_vs_intergenomic_seqs_test    0.000369
# 24999  demo_coding_vs_intergenomic_seqs_test    0.013915
#
# [1704026 rows x 6 columns]

# %% [markdown]
# ## Caluclate Values for ROC -Curves

# %%
def df2rocdf(df,reference,sample):
    metasamplename = ' / '.join([reference,sample])
    label, prediction = df["Label"],df["Prediction"]

    fpr,tpr, p = metrics.roc_curve(label,prediction,pos_label=1)
    return pd.DataFrame({"False Positive Rate":fpr, "Recall":tpr, "Points":p,"Reference":reference,"Sample":sample})

                

roc_temp = []

order = {"SARS-CoV-2":"SARS-CoV-2"}

for e in readseeker_result["Reference"].unique():
    order[e]=e

for reference in order:
    #print(reference)
    reference_subset = readseeker_result.loc[readseeker_result["Reference"]==reference,:]
    samples = reference_subset["Sample"].unique()
    
    for sample in samples:
        print(sample)
        samplesubset = reference_subset.loc[reference_subset["Sample"]==sample,:]
        roc_temp.append(df2rocdf(samplesubset,reference,sample))
        
    if len(samples) >1:
        roc_temp.append(df2rocdf(reference_subset,reference,"Average"))
    
ROC_plotdata = pd.concat(roc_temp)
#display(ROC_plotdata)
# Out:
# ERR10913059
# ERR10913061
# SRR22674487
# ERR2024408
# ERR10492982
# ERR10493241
# ERR10509672
# DRR317657
# SRR21820122
# SRR21820124
# SRR21864655
# demo_coding_vs_intergenomic_seqs_test

# %% [markdown]
# # Assign labels to classification results
#
# This function will assign the labels True Positive, True Negative,False Negative and False Positive to the reads. 0.5 is used as prediction cuttoff to distiguish between positive and negative prediction results.

# %%
decions = readseeker_result.copy()
decions["BinaryDecision"] = "coding"
decions.loc[decions.loc[:,"Prediction"]<0.5,"BinaryDecision"] = "noncoding"
decions["Class"] = "None"
decions.loc[(decions.loc[:,"Prediction"]>=0.5)&(decions.loc[:,"Label"]==1),"Class"] = "True Positive"
decions.loc[(decions.loc[:,"Prediction"]<0.5)&(decions.loc[:,"Label"]==0),"Class"] = "True Negative"
decions.loc[(decions.loc[:,"Prediction"]>=0.5)&(decions.loc[:,"Label"]==0),"Class"] = "False Positive"
decions.loc[(decions.loc[:,"Prediction"]<0.5)&(decions.loc[:,"Label"]==1),"Class"] = "False Negative"

# Convert to Countdata
decisions3=decions.groupby(['Reference',"Class"]).size().reset_index().pivot(columns='Class', index='Reference', values=0).fillna(0).reindex(["False Negative","False Positive","True Negative","True Positive",],axis=1)
display(decisions3)

# Normalize to Percent
decisions4 = decisions3.div(decisions3.agg("sum",axis=1)/100,axis="rows")
decisions4["Accuracy"] = (decisions3["True Positive"]+decisions3["True Negative"])/(decisions3["True Positive"]+decisions3["True Negative"]+(decisions3["False Positive"]+decisions3["False Negative"]))
display(decisions4)
# Out:
# Class                       False Negative  False Positive  True Negative  \
# Reference
# Epstein-Barr Virus                 27471.0         18666.0       369588.0
# Escherichia coli                     225.0           515.0         7797.0
# Genomic Benchmark (Human)           1997.0           494.0        12006.0
# Human                               1644.0          1239.0        42755.0
# Mus musculus                         412.0           386.0        12577.0
# Mycobacterium tuberculosis           309.0          1357.0        14732.0
# SARS-CoV-2                         70381.0             0.0            8.0
#
# Class                       True Positive
# Reference
# Epstein-Barr Virus               360783.0
# Escherichia coli                   8087.0
# Genomic Benchmark (Human)         10503.0
# Human                             42350.0
# Mus musculus                      12551.0
# Mycobacterium tuberculosis        15780.0
# SARS-CoV-2                       669413.0
# Class                       False Negative  False Positive  True Negative  \
# Reference
# Epstein-Barr Virus                3.537761        2.403839      47.596161
# Escherichia coli                  1.353465        3.097931      46.902069
# Genomic Benchmark (Human)         7.988000        1.976000      48.024000
# Human                             1.868437        1.408147      48.591853
# Mus musculus                      1.589138        1.488853      48.511147
# Mycobacterium tuberculosis        0.960283        4.217167      45.782833
# SARS-CoV-2                        9.513491        0.000000       0.001081
#
# Class                       True Positive  Accuracy
# Reference
# Epstein-Barr Virus              46.462239  0.940584
# Escherichia coli                48.646535  0.955486
# Genomic Benchmark (Human)       42.012000  0.900360
# Human                           48.131563  0.967234
# Mus musculus                    48.410862  0.969220
# Mycobacterium tuberculosis      49.039717  0.948225
# SARS-CoV-2                      90.485427  0.904865

# %% [markdown]
# ## Ploting

# %%
# %matplotlib inline

sns.set(rc={'figure.figsize':(15,18)})
sns.set_style("whitegrid")

fig, axes = plt.subplot_mosaic([['1A'], ['1B']],layout='constrained')


## Result Barplot  2A




p=decisions4[["False Negative","False Positive","True Negative","True Positive"]].plot(kind='barh', stacked=True, ylabel='Percentage', xlabel='Reference',ax=axes["1A"],
                        color={'False Negative':'#D81BC3',
                       'False Positive':'#FF6907',
                       'True Negative':"#1EA9E5",
                       'True Positive':"#004D0A"}
            )
p.set_title('Classification Results on Sequencing Based Ground Truth (Threshold 0.5)',fontdict={'size': 14, 'weight': 'bold'})
    #p.tick_params(axis='x', rotation=20,labelright=True)
p.set_xticks(range(0,101,5))
p.legend(title='', loc='lower center',bbox_to_anchor=(0.5, -0.1),ncol =4)
threshold = 1.6
for c in p.containers:
    # Filter the labels
    labels = ["%.1f%%"%v if v > threshold else "" for v in c.datavalues]    
    p.bar_label(c, labels=labels, label_type="center", color = "white", rotation=90)








## ROC PLOT  2B

ROC_plotdata =ROC_plotdata.assign(Metasample = ROC_plotdata[["Reference","Sample"]].agg(' / '.join, axis=1))
colors = ["#FF3400","#1E88E5","#D81B60","#FFC107","#0d004d","#004D40","#000000"]

noAVG = {'Escherichia coli / SRR22674487', 'Epstein-Barr Virus / ERR2024408','Mus musculus / ERR3021870','Genomic Benchmark (Human) / demo_coding_vs_intergenomic_seqs_test'}

colperREF = {x:y for x,y in zip(ROC_plotdata.loc[:,"Reference"].unique(),colors)}

#print(colperREF)
#print([x for x in ROC_plotdata.loc[:,"Metasample"].unique()])


metapal = {x:colperREF["/".join(x.split(" / ")[:-1])]+("" if x.endswith("Average") or x in noAVG else "AA") for x in ROC_plotdata.loc[:,"Metasample"].unique()}






metadash = {x+" / "+y: ["",(3,1),(1,1),(2,1)][int(y != "Average" and ((x+" / "+y) not in noAVG))*(i+1)]
                 for x in ROC_plotdata.loc[:,"Reference"].unique() for i,y in enumerate(list( ROC_plotdata.loc[ROC_plotdata.loc[:,"Reference"]==x,"Sample"].unique()))}

roc_plot = sns.lineplot(ax=axes["1B"],data=ROC_plotdata,y="Recall",x="False Positive Rate",hue = "Metasample",style="Metasample",estimator=None,dashes=metadash,palette=metapal)

roc_plot.set_title("ROC Curve - Readseeker Model on Sequencing Based Ground Truth", fontdict={'size': 14, 'weight': 'bold'})
roc_plot.legend().set_title(None)
sns.lineplot(ax= axes["1B"],x=[0,1],y=[0,1],color=(0.8,0.8,0.8),linestyle="--",estimator=None)

# Set Subfigure Labels
for label,ax in axes.items():
    ax.set_title(label,fontdict={'size': 16, 'weight': 'bold'}, loc='left', fontsize='medium')

os.makedirs("plots", exist_ok=True)
fig.savefig("plots/roc_plot.svg", format='svg')
fig.savefig("plots/roc_plot.eps", format="eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ##  Load FragGeneScan Data

# %%
fraggene_result_filename = "../benchmark_result/fraggene_classification_benchmark_11Samples_6References.tsv"
fraggene_result = pandas.read_csv(fraggene_result_filename,sep ="\t",lineterminator='\n',index_col = None)

fraggene_result_filename2 = "../benchmark_result/fraggene_classification_benchmark_injected_1Samples_1References.tsv"
fraggene_result2 = pandas.read_csv(fraggene_result_filename2,sep ="\t",lineterminator='\n',index_col = None)

fraggene_result = pd.concat([fraggene_result, fraggene_result2], axis=0)
# Rename reference sequences as above 
fraggene_result = fraggene_result.replace({"Reference":renameSamples})
display(fraggene_result)
# Out:
#                        Reference                            Sample  \
# 0               Escherichia coli                       SRR22674487
# 1               Escherichia coli                       SRR22674487
# 2               Escherichia coli                       SRR22674487
# 3               Escherichia coli                       SRR22674487
# 4               Escherichia coli                       SRR22674487
# ...                          ...                               ...
# 24995  Genomic Benchmark (Human)  demo_coding_vs_intergenomic_seqs
# 24996  Genomic Benchmark (Human)  demo_coding_vs_intergenomic_seqs
# 24997  Genomic Benchmark (Human)  demo_coding_vs_intergenomic_seqs
# 24998  Genomic Benchmark (Human)  demo_coding_vs_intergenomic_seqs
# 24999  Genomic Benchmark (Human)  demo_coding_vs_intergenomic_seqs
#
#                                                     Name  cdsbases  \
# 0                            SRR22674487.819286_2-42-0-1       148
# 1                            SRR22674487.287945_2-42-0-1       147
# 2                             SRR22674487.58161_2-42-0-1       147
# 3                            SRR22674487.371638_2-42-0-1       147
# 4                            SRR22674487.956120_2-42-0-1       150
# ...                                                  ...       ...
# 24995  demo_coding_vs_intergenomic_seqs/test/intergen...         0
# 24996  demo_coding_vs_intergenomic_seqs/test/intergen...       198
# 24997  demo_coding_vs_intergenomic_seqs/test/intergen...         0
# 24998  demo_coding_vs_intergenomic_seqs/test/intergen...         0
# 24999  demo_coding_vs_intergenomic_seqs/test/intergen...       198
#
#        totallength  fraction  PredictedLabel  Label
# 0              151  0.980132               1      1
# 1              151  0.973510               1      1
# 2              151  0.973510               1      1
# 3              151  0.973510               1      1
# 4              151  0.993377               1      1
# ...            ...       ...             ...    ...
# 24995          200  0.000000               0      0
# 24996          200  0.990000               1      0
# 24997          200  0.000000               0      0
# 24998          200  0.000000               0      0
# 24999          200  0.990000               1      0
#
# [1704026 rows x 8 columns]

# %% [markdown]
# ## Load Simple Base Model Data

# %%
import glob

sbds = []
for data in glob.glob("simple_model_results/*.tsv"):
    sbds.append(pandas.read_csv(data,sep ="\t",lineterminator='\n'))

sbds_df = pandas.concat(sbds)
sbds_df.replace({"Reference":renameSamples},inplace= True)
print(sbds_df)
# Out:
#               Reference       Sample  Prediction  Label  PredictedLabel
# 0      Escherichia coli  SRR22674487    0.999829      1               1
# 1      Escherichia coli  SRR22674487    0.999784      1               1
# 2      Escherichia coli  SRR22674487    0.999968      1               1
# 3      Escherichia coli  SRR22674487    0.794678      1               1
# 4      Escherichia coli  SRR22674487    0.831682      1               1
# ...                 ...          ...         ...    ...             ...
# 31637             Human  ERR10492982    0.301690      0               0
# 31638             Human  ERR10492982    0.993499      0               1
# 31639             Human  ERR10492982    0.102710      0               0
# 31640             Human  ERR10492982    0.427420      0               0
# 31641             Human  ERR10492982    0.556391      0               1
#
# [1704026 rows x 5 columns]

# %% [markdown]
# # Calculate Metrics

# %%
coefr  = readseeker_result.copy()
coefr["PredictedLabel"] = 0
coefr.loc[coefr.loc[:,"Prediction"]>=0.5,"PredictedLabel"] =1


def metricsSubset(subset):

    accuracy = metrics.accuracy_score(subset["Label"],subset["PredictedLabel"])
    
    fpr,tpr, _ = metrics.roc_curve(subset["Label"],subset["Prediction"],pos_label=1)
    roc_auc = metrics.auc(fpr,tpr)
    F1 = metrics.f1_score(subset["Label"],subset["PredictedLabel"])
    MCC = metrics.matthews_corrcoef(subset["Label"],subset["PredictedLabel"])

        
    return {"Reference":"","Accuracy":accuracy,"ROC-AUC":roc_auc,"F1":F1,"MCC":MCC}

def get_metrics(df):
    references = set(df["Reference"])
    r = []
    for reference in references:
        tr = metricsSubset(df.loc[df["Reference"]==reference,:])
        tr["Reference"]=reference
        r.append(tr)
    tr = metricsSubset(df)
    tr["Reference"]="Overall"
    
    r.append(tr)
    return pd.DataFrame(r)
    
readseeker_performance = get_metrics(coefr)
    
display(readseeker_performance)
# Out:
#                     Reference  Accuracy   ROC-AUC        F1       MCC
# 0            Escherichia coli  0.955486  0.992511  0.956249  0.911527
# 1                  SARS-CoV-2  0.904865  0.995816  0.950056  0.010141
# 2          Epstein-Barr Virus  0.940584  0.987394  0.939903  0.881395
# 3  Mycobacterium tuberculosis  0.948225  0.988371  0.949859  0.898359
# 4                       Human  0.967234  0.994317  0.967083  0.934508
# 5   Genomic Benchmark (Human)  0.900360  0.964046  0.893986  0.806572
# 6                Mus musculus  0.969220  0.993639  0.969189  0.938442
# 7                     Overall  0.926588  0.981399  0.947084  0.832749

# %% [markdown]
# ### FragGeneScan

# %%
coefr_fgs  = fraggene_result.copy()

coefr_fgs["Prediction"]= coefr_fgs["fraction"]
fraggenescan_performance = get_metrics(coefr_fgs)

display(fraggenescan_performance)
# Out:
#                     Reference  Accuracy   ROC-AUC        F1       MCC
# 0            Escherichia coli  0.701155  0.809325  0.769552  0.499913
# 1                  SARS-CoV-2  0.992209  0.990406  0.996089 -0.000291
# 2          Epstein-Barr Virus  0.755186  0.870108  0.794221  0.551613
# 3  Mycobacterium tuberculosis  0.745509  0.839770  0.794602  0.559028
# 4                       Human  0.705051  0.818510  0.755064  0.449271
# 5   Genomic Benchmark (Human)  0.647320  0.737559  0.713371  0.332003
# 6                Mus musculus  0.737406  0.865750  0.789773  0.547607
# 7                     Overall  0.852938  0.880778  0.904649  0.618927

# %% [markdown]
# # simple model

# %%
#display(sbds_df)
sbm_performance = get_metrics(sbds_df)
display(sbm_performance)
# Out:
#                     Reference  Accuracy   ROC-AUC        F1       MCC
# 0            Escherichia coli  0.694057  0.901653  0.761780  0.471795
# 1                       Human  0.817600  0.902214  0.805015  0.640560
# 2          Epstein-Barr Virus  0.717045  0.875349  0.773424  0.500466
# 3  Mycobacterium tuberculosis  0.501336  0.901746  0.667261  0.036580
# 4                  SARS-CoV-2  0.473437  0.732711  0.642625  0.003118
# 5   Genomic Benchmark (Human)  0.889920  0.958391  0.892256  0.780574
# 6                Mus musculus  0.741881  0.841016  0.703106  0.501160
# 7                     Overall  0.615092  0.609345  0.709746  0.154129

# %% [markdown]
# ### Join and Generate LaTeX

# %%
fraggenescan_performance["Tool"] = "FragGeneScan"
readseeker_performance["Tool"] = "ReadSeeker"
sbm_performance["Tool"] = "Simple Base Model"

#fraggenescan_performance.reset_index(drop=True, inplace=True)
#readseeker_performance.reset_index(drop=True, inplace=True)


large_performance = pd.concat([readseeker_performance,fraggenescan_performance,sbm_performance])


# sort references

sorder = {"Epstein-Barr Virus":0, "Escherichia coli":2, "Human":4, "SARS-CoV-2":1,
          "Mycobacterium tuberculosis":3,"Mus musculus":5,"Genomic Benchmark (Human)":6,"Overall":7}
sorder2 = {"ReadSeeker":0,"FragGeneScan":1,"Simple Base Model":2}

large_performance["sorder"] = large_performance["Reference"].map(sorder)
large_performance["sorder2"] = large_performance["Reference"].map(sorder2)
large_performance.sort_values(by=[ 'sorder','sorder2'], ascending=[True, True], inplace=True)
large_performance.drop(columns=['sorder','sorder2'],inplace=True)



# Fit names for LaTeX Table
shortRefNames = {
    "Escherichia coli":"E. coli",
    "Mycobacterium tuberculosis":"M. tuberculosis",
    "Epstein-Barr Virus":"EBV"
    
}




large_performance["Reference"]= large_performance["Reference"].replace(shortRefNames)




large_performance.set_index(["Reference","Tool"],inplace=True)


# some style functions

def highlight_conditionally(val, number):

    if val >= number:
        return 'font-weight: bold'
    return ''

# Anwendung der Stilisierung mit MultiIndex-Betrachtung
def apply_highlight(x):

    
    max_in_reference = x.groupby(level='Reference').max()

    return [highlight_conditionally(z, max_in_reference[idx[0]]) for z,idx in zip(x, x.index)]

styled_df = large_performance.style.apply(apply_highlight, axis=0)
styled_df.set_table_styles([
    {'selector': 'toprule', 'props': ':hline;'},
    {'selector': 'midrule', 'props': ':hline;'},
#    {'selector': 'bottomrule', 'props': ':hline;'},
], overwrite=True)

styled_df.format({"Accuracy": '{:.4f}',"ROC-AUC": '{:.4f}',"F1": '{:.4f}',"MCC": '{:.4f}'})
display(styled_df)
# Out:
# <style type="text/css">
# #T_2dfb3 toprule {
#   : hline;
# }
# #T_2dfb3 midrule {
#   : hline;
# }
# #T_2dfb3_row0_col0, #T_2dfb3_row0_col1, #T_2dfb3_row0_col2, #T_2dfb3_row0_col3, #T_2dfb3_row3_col1, #T_2dfb3_row3_col3, #T_2dfb3_row4_col0, #T_2dfb3_row4_col2, #T_2dfb3_row6_col0, #T_2dfb3_row6_col1, #T_2dfb3_row6_col2, #T_2dfb3_row6_col3, #T_2dfb3_row9_col0, #T_2dfb3_row9_col1, #T_2dfb3_row9_col2, #T_2dfb3_row9_col3, #T_2dfb3_row12_col0, #T_2dfb3_row12_col1, #T_2dfb3_row12_col2, #T_2dfb3_row12_col3, #T_2dfb3_row15_col0, #T_2dfb3_row15_col1, #T_2dfb3_row15_col2, #T_2dfb3_row15_col3, #T_2dfb3_row18_col0, #T_2dfb3_row18_col1, #T_2dfb3_row18_col2, #T_2dfb3_row18_col3, #T_2dfb3_row21_col0, #T_2dfb3_row21_col1, #T_2dfb3_row21_col2, #T_2dfb3_row21_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_2dfb3">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2dfb3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2dfb3_level0_col1" class="col_heading level0 col1" >ROC-AUC</th>
#       <th id="T_2dfb3_level0_col2" class="col_heading level0 col2" >F1</th>
#       <th id="T_2dfb3_level0_col3" class="col_heading level0 col3" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Reference</th>
#       <th class="index_name level1" >Tool</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dfb3_level0_row0" class="row_heading level0 row0" rowspan="3">EBV</th>
#       <th id="T_2dfb3_level1_row0" class="row_heading level1 row0" >ReadSeeker</th>
#       <td id="T_2dfb3_row0_col0" class="data row0 col0" >0.9406</td>
#       <td id="T_2dfb3_row0_col1" class="data row0 col1" >0.9874</td>
#       <td id="T_2dfb3_row0_col2" class="data row0 col2" >0.9399</td>
#       <td id="T_2dfb3_row0_col3" class="data row0 col3" >0.8814</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level1_row1" class="row_heading level1 row1" >FragGeneScan</th>
#       <td id="T_2dfb3_row1_col0" class="data row1 col0" >0.7552</td>
#       <td id="T_2dfb3_row1_col1" class="data row1 col1" >0.8701</td>
#       <td id="T_2dfb3_row1_col2" class="data row1 col2" >0.7942</td>
#       <td id="T_2dfb3_row1_col3" class="data row1 col3" >0.5516</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level1_row2" class="row_heading level1 row2" >Simple Base Model</th>
#       <td id="T_2dfb3_row2_col0" class="data row2 col0" >0.7170</td>
#       <td id="T_2dfb3_row2_col1" class="data row2 col1" >0.8753</td>
#       <td id="T_2dfb3_row2_col2" class="data row2 col2" >0.7734</td>
#       <td id="T_2dfb3_row2_col3" class="data row2 col3" >0.5005</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level0_row3" class="row_heading level0 row3" rowspan="3">SARS-CoV-2</th>
#       <th id="T_2dfb3_level1_row3" class="row_heading level1 row3" >ReadSeeker</th>
#       <td id="T_2dfb3_row3_col0" class="data row3 col0" >0.9049</td>
#       <td id="T_2dfb3_row3_col1" class="data row3 col1" >0.9958</td>
#       <td id="T_2dfb3_row3_col2" class="data row3 col2" >0.9501</td>
#       <td id="T_2dfb3_row3_col3" class="data row3 col3" >0.0101</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level1_row4" class="row_heading level1 row4" >FragGeneScan</th>
#       <td id="T_2dfb3_row4_col0" class="data row4 col0" >0.9922</td>
#       <td id="T_2dfb3_row4_col1" class="data row4 col1" >0.9904</td>
#       <td id="T_2dfb3_row4_col2" class="data row4 col2" >0.9961</td>
#       <td id="T_2dfb3_row4_col3" class="data row4 col3" >-0.0003</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level1_row5" class="row_heading level1 row5" >Simple Base Model</th>
#       <td id="T_2dfb3_row5_col0" class="data row5 col0" >0.4734</td>
#       <td id="T_2dfb3_row5_col1" class="data row5 col1" >0.7327</td>
#       <td id="T_2dfb3_row5_col2" class="data row5 col2" >0.6426</td>
#       <td id="T_2dfb3_row5_col3" class="data row5 col3" >0.0031</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level0_row6" class="row_heading level0 row6" rowspan="3">E. coli</th>
#       <th id="T_2dfb3_level1_row6" class="row_heading level1 row6" >ReadSeeker</th>
#       <td id="T_2dfb3_row6_col0" class="data row6 col0" >0.9555</td>
#       <td id="T_2dfb3_row6_col1" class="data row6 col1" >0.9925</td>
#       <td id="T_2dfb3_row6_col2" class="data row6 col2" >0.9562</td>
#       <td id="T_2dfb3_row6_col3" class="data row6 col3" >0.9115</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level1_row7" class="row_heading level1 row7" >FragGeneScan</th>
#       <td id="T_2dfb3_row7_col0" class="data row7 col0" >0.7012</td>
#       <td id="T_2dfb3_row7_col1" class="data row7 col1" >0.8093</td>
#       <td id="T_2dfb3_row7_col2" class="data row7 col2" >0.7696</td>
#       <td id="T_2dfb3_row7_col3" class="data row7 col3" >0.4999</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level1_row8" class="row_heading level1 row8" >Simple Base Model</th>
#       <td id="T_2dfb3_row8_col0" class="data row8 col0" >0.6941</td>
#       <td id="T_2dfb3_row8_col1" class="data row8 col1" >0.9017</td>
#       <td id="T_2dfb3_row8_col2" class="data row8 col2" >0.7618</td>
#       <td id="T_2dfb3_row8_col3" class="data row8 col3" >0.4718</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level0_row9" class="row_heading level0 row9" rowspan="3">M. tuberculosis</th>
#       <th id="T_2dfb3_level1_row9" class="row_heading level1 row9" >ReadSeeker</th>
#       <td id="T_2dfb3_row9_col0" class="data row9 col0" >0.9482</td>
#       <td id="T_2dfb3_row9_col1" class="data row9 col1" >0.9884</td>
#       <td id="T_2dfb3_row9_col2" class="data row9 col2" >0.9499</td>
#       <td id="T_2dfb3_row9_col3" class="data row9 col3" >0.8984</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level1_row10" class="row_heading level1 row10" >FragGeneScan</th>
#       <td id="T_2dfb3_row10_col0" class="data row10 col0" >0.7455</td>
#       <td id="T_2dfb3_row10_col1" class="data row10 col1" >0.8398</td>
#       <td id="T_2dfb3_row10_col2" class="data row10 col2" >0.7946</td>
#       <td id="T_2dfb3_row10_col3" class="data row10 col3" >0.5590</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level1_row11" class="row_heading level1 row11" >Simple Base Model</th>
#       <td id="T_2dfb3_row11_col0" class="data row11 col0" >0.5013</td>
#       <td id="T_2dfb3_row11_col1" class="data row11 col1" >0.9017</td>
#       <td id="T_2dfb3_row11_col2" class="data row11 col2" >0.6673</td>
#       <td id="T_2dfb3_row11_col3" class="data row11 col3" >0.0366</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level0_row12" class="row_heading level0 row12" rowspan="3">Human</th>
#       <th id="T_2dfb3_level1_row12" class="row_heading level1 row12" >ReadSeeker</th>
#       <td id="T_2dfb3_row12_col0" class="data row12 col0" >0.9672</td>
#       <td id="T_2dfb3_row12_col1" class="data row12 col1" >0.9943</td>
#       <td id="T_2dfb3_row12_col2" class="data row12 col2" >0.9671</td>
#       <td id="T_2dfb3_row12_col3" class="data row12 col3" >0.9345</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level1_row13" class="row_heading level1 row13" >FragGeneScan</th>
#       <td id="T_2dfb3_row13_col0" class="data row13 col0" >0.7051</td>
#       <td id="T_2dfb3_row13_col1" class="data row13 col1" >0.8185</td>
#       <td id="T_2dfb3_row13_col2" class="data row13 col2" >0.7551</td>
#       <td id="T_2dfb3_row13_col3" class="data row13 col3" >0.4493</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level1_row14" class="row_heading level1 row14" >Simple Base Model</th>
#       <td id="T_2dfb3_row14_col0" class="data row14 col0" >0.8176</td>
#       <td id="T_2dfb3_row14_col1" class="data row14 col1" >0.9022</td>
#       <td id="T_2dfb3_row14_col2" class="data row14 col2" >0.8050</td>
#       <td id="T_2dfb3_row14_col3" class="data row14 col3" >0.6406</td>
#     </tr>
#     <tr>
#       <th id="T_2dfb3_level0_row15" class="row_heading level0 row15" rowspan="3">Mus musculus</th>
#       <th id="T_2dfb3_level1_row15" class="row_heading level1 row15" >ReadSeeker</th>
#       <td id="T_2dfb3_row15

# %%
print(styled_df
      .format_index("\\textit{{{}}}", escape="latex", axis=0)
      .to_latex(clines="skip-last;data",caption="\\textbf{\\textit{ReadSeeker}-model, \\textit{FragGeneScan} and Genomic Benchmark \\textit{Base Model} benchmark metrics}",label="qualmeasurmentstable",column_format="|l|l|r|r|r|r|",convert_css=True)
      #.replace("\\\\\n\\m","\\\\\hline\n\\m")
      .replace("\\end{tabular}\n","\\end{tabular}\n\\input{Tables/performance_table_desc}")
      .replace("\\begin{table}","\\begin{table}[!ht]"))
# Out:
# \begin{table}[!ht]
# \caption{\textbf{\textit{ReadSeeker}-model, \textit{FragGeneScan} and Genomic Benchmark \textit{Base Model} benchmark metrics}}
# \label{qualmeasurmentstable}
# \begin{tabular}{|l|l|r|r|r|r|}
# \hline
#  &  & Accuracy & ROC-AUC & F1 & MCC \\
# Reference & Tool &  &  &  &  \\
# \hline
# \multirow[c]{3}{*}{\textit{EBV}} & \textit{ReadSeeker} & \bfseries 0.9406 & \bfseries 0.9874 & \bfseries 0.9399 & \bfseries 0.8814 \\
#  & \textit{FragGeneScan} & 0.7552 & 0.8701 & 0.7942 & 0.5516 \\
#  & \textit{Simple Base Model} & 0.7170 & 0.8753 & 0.7734 & 0.5005 \\
# \cline{1-6}
# \multirow[c]{3}{*}{\textit{SARS-CoV-2}} & \textit{ReadSeeker} & 0.9049 & \bfseries 0.9958 & 0.9501 & \bfseries 0.0101 \\
#  & \textit{FragGeneScan} & \bfseries 0.9922 & 0.9904 & \bfseries 0.9961 & -0.0003 \\
#  & \textit{Simple Base Model} & 0.4734 & 0.7327 & 0.6426 & 0.0031 \\
# \cline{1-6}
# \multirow[c]{3}{*}{\textit{E. coli}} & \textit{ReadSeeker} & \bfseries 0.9555 & \bfseries 0.9925 & \bfseries 0.9562 & \bfseries 0.9115 \\
#  & \textit{FragGeneScan} & 0.7012 & 0.8093 & 0.7696 & 0.4999 \\
#  & \textit{Simple Base Model} & 0.6941 & 0.9017 & 0.7618 & 0.4718 \\
# \cline{1-6}
# \multirow[c]{3}{*}{\textit{M. tuberculosis}} & \textit{ReadSeeker} & \bfseries 0.9482 & \bfseries 0.9884 & \bfseries 0.9499 & \bfseries 0.8984 \\
#  & \textit{FragGeneScan} & 0.7455 & 0.8398 & 0.7946 & 0.5590 \\
#  & \textit{Simple Base Model} & 0.5013 & 0.9017 & 0.6673 & 0.0366 \\
# \cline{1-6}
# \multirow[c]{3}{*}{\textit{Human}} & \textit{ReadSeeker} & \bfseries 0.9672 & \bfseries 0.9943 & \bfseries 0.9671 & \bfseries 0.9345 \\
#  & \textit{FragGeneScan} & 0.7051 & 0.8185 & 0.7551 & 0.4493 \\
#  & \textit{Simple Base Model} & 0.8176 & 0.9022 & 0.8050 & 0.6406 \\
# \cline{1-6}
# \multirow[c]{3}{*}{\textit{Mus musculus}} & \textit{ReadSeeker} & \bfseries 0.9692 & \bfseries 0.9936 & \bfseries 0.9692 & \bfseries 0.9384 \\
#  & \textit{FragGeneScan} & 0.7374 & 0.8658 & 0.7898 & 0.5476 \\
#  & \textit{Simple Base Model} & 0.7419 & 0.8410 & 0.7031 & 0.5012 \\
# \cline{1-6}
# \multirow[c]{3}{*}{\textit{Genomic Benchmark (Human)}} & \textit{ReadSeeker} & \bfseries 0.9004 & \bfseries 0.9640 & \bfseries 0.8940 & \bfseries 0.8066 \\
#  & \textit{FragGeneScan} & 0.6473 & 0.7376 & 0.7134 & 0.3320 \\
#  & \textit{Simple Base Model} & 0.8899 & 0.9584 & 0.8923 & 0.7806 \\
# \cline{1-6}
# \multirow[c]{3}{*}{\textit{Overall}} & \textit{ReadSeeker} & \bfseries 0.9266 & \bfseries 0.9814 & \bfseries 0.9471 & \bfseries 0.8327 \\
#  & \textit{FragGeneScan} & 0.8529 & 0.8808 & 0.9046 & 0.6189 \\
#  & \textit{Simple Base Model} & 0.6151 & 0.6093 & 0.7097 & 0.1541 \\
# \cline{1-6}
# \end{tabular}
# \input{Tables/performance_table_desc}\end{table}

# %% [markdown]
# #  Suplemental confusion matrices
# ## Readseeker

# %%
# confusion plot order


porder = {"Epstein-Barr Virus":(0,0), "Escherichia coli":(0,1), "Human":(1,2), "SARS-CoV-2":(1,0),
          "Mycobacterium tuberculosis":(1,1),"Mus musculus":(0,2),"Genomic Benchmark (Human)":(2,2)}

def plot_confusionmatrix(dataorigin,result, porder,image_index):
    

    references = set(result["Reference"])
    print(references)
    matrices = dict()

    fig, axes = plt.subplots(3, 3  , sharex=False, figsize=(15,15), constrained_layout=True)
    fig.text(0.05, 0.99, image_index, fontsize=16, fontweight='bold', ha='left', va='top')
    #axes[0][0].set_title("S1",fontdict={'size': 16, 'weight': 'bold'}, loc='left', fontsize='medium')
    
    fig.suptitle(f"{dataorigin} Confusion Matrices",size= 14, weight= 'bold')

    #fig.suptitle(f"{dataorigin} Confusionmatrices",fontdict={'size': 14, 'weight': 'bold'})

    for ref in references: 
        subset = result.loc[result["Reference"]==ref,:]

        ## Adapted from https://medium.com/@dtuk81/confusion-matrix-visualization-fc31e3f30fea
        cf_matrix = confusion_matrix( subset["Label"],subset["PredictedLabel"])

        group_names = ["True Neg","False Pos","False Neg","True Pos"]
        group_counts = ["#{0:0.0f}".format(value) for value in cf_matrix.flatten()]
        group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
        labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
        labels = np.asarray(labels).reshape(2,2)


        sns.heatmap(cf_matrix/np.sum(cf_matrix)*100,ax= axes[porder[ref][0]][porder[ref][1]], annot=labels, 
               fmt='', cmap='Blues',vmin=0, vmax=50)
        do = "Simple Base Model" if dataorigin.startswith("Genomic Benchmark Simple Base Model") else dataorigin
        axes[porder[ref][0]][porder[ref][1]].set(ylabel='Reference Annotation', xlabel=f'{do} Label',title=(ref+" (unbalanced)" if ref=="SARS-CoV-2" else ref))
    
    #Remove Axis on empty plots
    axes[2, 0].axis('off')
    axes[2, 1].axis('off')
    return (fig,axes)

f1, a = plot_confusionmatrix("ReadSeeker", coefr,porder,image_index="S2")

f1.savefig("plots/Readseeker_confusion.eps", format="eps")
f1.savefig("plots/Readseeker_confusion.svg", format="svg")
f1
# Out:
# {'Escherichia coli', 'SARS-CoV-2', 'Epstein-Barr Virus', 'Mycobacterium tuberculosis', 'Human', 'Genomic Benchmark (Human)', 'Mus musculus'}

# %% [markdown]
# ## FragGeneScan

# %%
f2, a = plot_confusionmatrix("FragGeneScan", coefr_fgs,porder,image_index="S3")
f2.savefig("plots/FragGeneScan_confusion.eps", format="eps")
f2.savefig("plots/FragGeneScan_confusion.svg", format="svg")
f2
# Out:
# {'Escherichia coli', 'SARS-CoV-2', 'Epstein-Barr Virus', 'Mycobacterium tuberculosis', 'Human', 'Genomic Benchmark (Human)', 'Mus musculus'}

# %% [markdown]
# ## Genome Benchmark *Simple Base Model*

# %%
f3, a = plot_confusionmatrix("Genomic Benchmark Simple Base Model", sbds_df,porder,image_index="S4")
f3.savefig("plots/GBBaseModel_confusion.eps", format="eps")
f3.savefig("plots/GBBaseModel_confusion.svg", format="svg")
f3
# Out:
# {'Escherichia coli', 'Human', 'Epstein-Barr Virus', 'Mycobacterium tuberculosis', 'SARS-CoV-2', 'Genomic Benchmark (Human)', 'Mus musculus'}

# %% [markdown]
# ## Generate Read Statisics

# %%
filtered_reads={(sample,reference):[f"../benchmark/{reference}/{sample}/{sample}_reads.fasta"] for reference, sample in [('human','ERR10493241'),
                                                                                             ('human','ERR10492982'),
                                                                                             ('human','ERR10509672'),
                                                                                             ('human_bm','demo_coding_vs_intergenomic_seqs'),
                                                                                             ('sars2','ERR10913059'),
                                                                                             ('sars2','ERR10913061'),
                                                                                             ('ecoli','SRR22674487'),
                                                                                             ('mycobacteriumtubercolosis','SRR21820122'),
                                                                                             ('mycobacteriumtubercolosis','SRR21864655'),
                                                                                             ('mycobacteriumtubercolosis','SRR21820124'),
                                                                                             ('gammaherpes4','ERR2024408'),
                                                                                             ('mouse','DRR317657')]}

# %%
rliste = []

unknowns = set()
for (sample,reference) ,l in filtered_reads.items():
    readl=[]
    ncount = 0
    nreadswithns = 0
    readcount = 0
    for e in l:
    
        with open(e,"r") as f:
            f.readline()
            seq = f.readline()
            while seq:
                sseq = seq.strip().upper()
            
                readl.append(len(sseq))
                unknown = [base for base in sseq if base not in {"A","C","G","T"}]
                readcount += 1
                if unknown:
                    unknowns.update(set(unknown))
                    ncount +=len(unknown)
                    nreadswithns += 1
                
                
                f.readline()
                seq = f.readline()
    rliste.append({"Sample":sample,"Reference":reference ,"min_rl":min(readl),"max_rl":max(readl),"avg_rl":sum(readl)/len(readl),"N_count":ncount, "Reads_with_ns":nreadswithns, "Number_of_Reads":readcount,"Percent_Nreads":nreadswithns/readcount*100})

readcounts = pandas.DataFrame(data=rliste)
readcounts.set_index("Sample",inplace=True)
display(readcounts)
# Out:
#                                                   Reference  min_rl  max_rl  \
# Sample
# ERR10493241                                           human     251     251
# ERR10492982                                           human     251     251
# ERR10509672                                           human     251     251
# demo_coding_vs_intergenomic_seqs                   human_bm     200     200
# ERR10913059                                           sars2     140     301
# ERR10913061                                           sars2     140     301
# SRR22674487                                           ecoli     151     151
# SRR21820122                       mycobacteriumtubercolosis     301     301
# SRR21864655                       mycobacteriumtubercolosis     301     301
# SRR21820124                       mycobacteriumtubercolosis     301     301
# ERR2024408                                     gammaherpes4     300     300
# DRR317657                                             mouse     250     255
#
#                                       avg_rl  N_count  Reads_with_ns  \
# Sample
# ERR10493241                       251.000000       38             22
# ERR10492982                       251.000000       25             21
# ERR10509672                       251.000000       33             20
# demo_coding_vs_intergenomic_seqs  200.000000        0              0
# ERR10913059                       252.216276      345            215
# ERR10913061                       258.031592      177            115
# SRR22674487                       151.000000      245            239
# SRR21820122                       301.000000        0              0
# SRR21864655                       301.000000        0              0
# SRR21820124                       301.000000        0              0
# ERR2024408                        300.000000        0              0
# DRR317657                         250.397092      143             45
#
#                                   Number_of_Reads  Percent_Nreads
# Sample
# ERR10493241                                 32084        0.068570
# ERR10492982                                 31642        0.066367
# ERR10509672                                 24262        0.082433
# demo_coding_vs_intergenomic_seqs            25000        0.000000
# ERR10913059                                427828        0.050254
# ERR10913061                                311974        0.036862
# SRR22674487                                 16624        1.437680
# SRR21820122                                  9718        0.000000
# SRR21864655                                 12576        0.000000
# SRR21820124                                  9884        0.000000
# ERR2024408                                 776508        0.000000
# DRR317657                                   25926        0.173571

# %%
read_count_base_data = pd.DataFrame([["mammal" , "human (GRCh38)" , "ERR10492982" , "-",   "balanced" ],
["mammal" , "human (GRCh38)" , "ERR10493241" , "-",   "balanced"  ],
["mammal" , "human (GRCh38)" , "ERR10509672" , "-",   "balanced" ],
["mammal" , "Genomic Benchmark (human)" , "demo_coding_vs_intergenomic_seqs" , "-",   "balanced" ],
["mammal" , "Mus musculus (NC_000067.7)" , "DRR317657" , "-",   "balanced" ],
["bacterial" , "M.tuberculosis (NC_000962.3)",  "SRR21820122" , "1762" , "balanced" ],
["bacterial" , "M.tuberculosis (NC_000962.3)",  "SRR21820124" , "1762" , "balanced"],
["bacterial" , "M.tuberculosis (NC_000962.3)",  "SRR21864655" , "1762" , "balanced"],
["bacterial" , "E.Coli (NC_000913.3)", "SRR22674487" , "561" , "balanced" , ],
["viral" , "EBV (GCF_002402265)" , "ERR2024408" , "548681" , "balanced" ],
["viral" , "SARS-CoV-2 (NC_045512.2)" , "ERR10913059" , "-",   "unbalanced" ],
["viral" , "SARS-CoV-2 (NC_045512.2) " , "ERR10913061" , "-",   "unbalanced" ]],
                                    columns =["Reference Category", "Reference", "SampleID", "Uniprot Taxon", "cds balancing"])

read_count_base_data["# Reads"] = read_count_base_data["SampleID"].map(readcounts["Number_of_Reads"])
read_count_base_data["Read length"] = read_count_base_data["SampleID"].map(readcounts["max_rl"])
read_count_base_data.replace ({"SampleID":{"demo_coding_vs_intergenomic_seqs":"coding/intergenomic"}},inplace=True)

read_count_base_data.reset_index(drop=True, inplace=True)

read_count_base_data_styled = read_count_base_data.style.set_table_styles([
    {'selector': 'toprule', 'props': ':hline;'},
    {'selector': 'midrule', 'props': ':hline;'},
    {'selector': 'bottomrule', 'props': ':hline;'},
], overwrite=True).hide(axis='index')
display(read_count_base_data_styled)
# Out:
# <style type="text/css">
# #T_5a8b0 toprule {
#   : hline;
# }
# #T_5a8b0 midrule {
#   : hline;
# }
# #T_5a8b0 bottomrule {
#   : hline;
# }
# </style>
# <table id="T_5a8b0">
#   <thead>
#     <tr>
#       <th id="T_5a8b0_level0_col0" class="col_heading level0 col0" >Reference Category</th>
#       <th id="T_5a8b0_level0_col1" class="col_heading level0 col1" >Reference</th>
#       <th id="T_5a8b0_level0_col2" class="col_heading level0 col2" >SampleID</th>
#       <th id="T_5a8b0_level0_col3" class="col_heading level0 col3" >Uniprot Taxon</th>
#       <th id="T_5a8b0_level0_col4" class="col_heading level0 col4" >cds balancing</th>
#       <th id="T_5a8b0_level0_col5" class="col_heading level0 col5" ># Reads</th>
#       <th id="T_5a8b0_level0_col6" class="col_heading level0 col6" >Read length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5a8b0_row0_col0" class="data row0 col0" >mammal</td>
#       <td id="T_5a8b0_row0_col1" class="data row0 col1" >human (GRCh38)</td>
#       <td id="T_5a8b0_row0_col2" class="data row0 col2" >ERR10492982</td>
#       <td id="T_5a8b0_row0_col3" class="data row0 col3" >-</td>
#       <td id="T_5a8b0_row0_col4" class="data row0 col4" >balanced</td>
#       <td id="T_5a8b0_row0_col5" class="data row0 col5" >31642</td>
#       <td id="T_5a8b0_row0_col6" class="data row0 col6" >251</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row1_col0" class="data row1 col0" >mammal</td>
#       <td id="T_5a8b0_row1_col1" class="data row1 col1" >human (GRCh38)</td>
#       <td id="T_5a8b0_row1_col2" class="data row1 col2" >ERR10493241</td>
#       <td id="T_5a8b0_row1_col3" class="data row1 col3" >-</td>
#       <td id="T_5a8b0_row1_col4" class="data row1 col4" >balanced</td>
#       <td id="T_5a8b0_row1_col5" class="data row1 col5" >32084</td>
#       <td id="T_5a8b0_row1_col6" class="data row1 col6" >251</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row2_col0" class="data row2 col0" >mammal</td>
#       <td id="T_5a8b0_row2_col1" class="data row2 col1" >human (GRCh38)</td>
#       <td id="T_5a8b0_row2_col2" class="data row2 col2" >ERR10509672</td>
#       <td id="T_5a8b0_row2_col3" class="data row2 col3" >-</td>
#       <td id="T_5a8b0_row2_col4" class="data row2 col4" >balanced</td>
#       <td id="T_5a8b0_row2_col5" class="data row2 col5" >24262</td>
#       <td id="T_5a8b0_row2_col6" class="data row2 col6" >251</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row3_col0" class="data row3 col0" >mammal</td>
#       <td id="T_5a8b0_row3_col1" class="data row3 col1" >Genomic Benchmark (human)</td>
#       <td id="T_5a8b0_row3_col2" class="data row3 col2" >coding/intergenomic</td>
#       <td id="T_5a8b0_row3_col3" class="data row3 col3" >-</td>
#       <td id="T_5a8b0_row3_col4" class="data row3 col4" >balanced</td>
#       <td id="T_5a8b0_row3_col5" class="data row3 col5" >25000</td>
#       <td id="T_5a8b0_row3_col6" class="data row3 col6" >200</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row4_col0" class="data row4 col0" >mammal</td>
#       <td id="T_5a8b0_row4_col1" class="data row4 col1" >Mus musculus (NC_000067.7)</td>
#       <td id="T_5a8b0_row4_col2" class="data row4 col2" >DRR317657</td>
#       <td id="T_5a8b0_row4_col3" class="data row4 col3" >-</td>
#       <td id="T_5a8b0_row4_col4" class="data row4 col4" >balanced</td>
#       <td id="T_5a8b0_row4_col5" class="data row4 col5" >25926</td>
#       <td id="T_5a8b0_row4_col6" class="data row4 col6" >255</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row5_col0" class="data row5 col0" >bacterial</td>
#       <td id="T_5a8b0_row5_col1" class="data row5 col1" >M.tuberculosis (NC_000962.3)</td>
#       <td id="T_5a8b0_row5_col2" class="data row5 col2" >SRR21820122</td>
#       <td id="T_5a8b0_row5_col3" class="data row5 col3" >1762</td>
#       <td id="T_5a8b0_row5_col4" class="data row5 col4" >balanced</td>
#       <td id="T_5a8b0_row5_col5" class="data row5 col5" >9718</td>
#       <td id="T_5a8b0_row5_col6" class="data row5 col6" >301</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row6_col0" class="data row6 col0" >bacterial</td>
#       <td id="T_5a8b0_row6_col1" class="data row6 col1" >M.tuberculosis (NC_000962.3)</td>
#       <td id="T_5a8b0_row6_col2" class="data row6 col2" >SRR21820124</td>
#       <td id="T_5a8b0_row6_col3" class="data row6 col3" >1762</td>
#       <td id="T_5a8b0_row6_col4" class="data row6 col4" >balanced</td>
#       <td id="T_5a8b0_row6_col5" class="data row6 col5" >9884</td>
#       <td id="T_5a8b0_row6_col6" class="data row6 col6" >301</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row7_col0" class="data row7 col0" >bacterial</td>
#       <td id="T_5a8b0_row7_col1" class="data row7 col1" >M.tuberculosis (NC_000962.3)</td>
#       <td id="T_5a8b0_row7_col2" class="data row7 col2" >SRR21864655</td>
#       <td id="T_5a8b0_row7_col3" class="data row7 col3" >1762</td>
#       <td id="T_5a8b0_row7_col4" class="data row7 col4" >balanced</td>
#       <td id="T_5a8b0_row7_col5" class="data row7 col5" >12576</td>
#       <td id="T_5a8b0_row7_col6" class="data row7 col6" >301</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row8_col0" class="data row8 col0" >bacterial</td>
#       <td id="T_5a8b0_row8_col1" class="data row8 col1" >E.Coli (NC_000913.3)</td>
#       <td id="T_5a8b0_row8_col2" class="data row8 col2" >SRR22674487</td>
#       <td id="T_5a8b0_row8_col3" class="data row8 col3" >561</td>
#       <td id="T_5a8b0_row8_col4" class="data row8 col4" >balanced</td>
#       <td id="T_5a8b0_row8_col5" class="data row8 col5" >16624</td>
#       <td id="T_5a8b0_row8_col6" class="data row8 col6" >151</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row9_col0" class="data row9 col0" >viral</td>
#       <td id="T_5a8b0_row9_col1" class="data row9 col1" >EBV (GCF_002402265)</td>
#       <td id="T_5a8b0_row9_col2" class="data row9 col2" >ERR2024408</td>
#       <td id="T_5a8b0_row9_col3" class="data row9 col3" >548681</td>
#       <td id="T_5a8b0_row9_col4" class="data row9 col4" >balanced</td>
#       <td id="T_5a8b0_row9_col5" class="data row9 col5" >776508</td>
#       <td id="T_5a8b0_row9_col6" class="data row9 col6" >300</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row10_col0" class="data row10 col0" >viral</td>
#       <td id="T_5a8b0_row10_col1" class="data row10 col1" >SARS-CoV-2 (NC_045512.2)</td>
#       <td id="T_5a8b0_row10_col2" class="data row10 col2" >ERR10913059</td>
#       <td id="T_5a8b0_row10_col3" class="data row10 col3" >-</td>
#       <td id="T_5a8b0_row10_col4" class="data row10 col4" >unbalanced</td>
#       <td id="T_5a8b0_row10_col5" class="data row10 col5" >427828</td>
#       <td id="T_5a8b0_row10_col6" class="data row10 col6" >301</td>
#     </tr>
#     <tr>
#       <td id="T_5a8b0_row11_col0" class="data row11 col0" >viral</td>
#       <td id="T_5a8b0_row11_col1" class="data row11 col1" >SARS-CoV-2 (NC_045512.2) </td>
#       <td id="T_5a8b0_row11_col2" class="data row11 col2" >ERR10913061</td>
#       <td id="T_5a8b0_row11_col3" class="data row11 col3" >-</td>
#       <td id="T_5a8b0_row11_col4" class="data row11 col4" >unbalanced</td>
#       <td id="T_5a8b0_row11_col5" class="data row11 col5" >311974</td>
#       <td id="T_5a8b0_row11_col6" class="data row11 col6" >301</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Read Statistics LaTeX

# %%
print(read_count_base_data_styled.to_latex(caption="\\textbf{Overview Test Dataset}",label="sampletable",column_format="|p{0.8in}|l|l|p{0.45in}|l|l|p{0.35in}|",convert_css=True).replace("\\\\\n\\m","\\\\\hline\n\\m").replace("\\end{tabular}\n","\\end{tabular}\n\\input{Tables/sampletable_table_desc}").replace("\\begin{table}","\\begin{table}[!ht]").replace("_","\\_").replace("#","\\#"))
# Out:
# \begin{table}[!ht]
# \caption{\textbf{Overview Test Dataset}}
# \label{sampletable}
# \begin{tabular}{|p{0.8in}|l|l|p{0.45in}|l|l|p{0.35in}|}
# \hline
# Reference Category & Reference & SampleID & Uniprot Taxon & cds balancing & \# Reads & Read length \\
# \hline
# mammal & human (GRCh38) & ERR10492982 & - & balanced & 31642 & 251 \\
# mammal & human (GRCh38) & ERR10493241 & - & balanced & 32084 & 251 \\
# mammal & human (GRCh38) & ERR10509672 & - & balanced & 24262 & 251 \\
# mammal & Genomic Benchmark (human) & coding/intergenomic & - & balanced & 25000 & 200 \\
# mammal & Mus musculus (NC\_000067.7) & DRR317657 & - & balanced & 25926 & 255 \\
# bacterial & M.tuberculosis (NC\_000962.3) & SRR21820122 & 1762 & balanced & 9718 & 301 \\
# bacterial & M.tuberculosis (NC\_000962.3) & SRR21820124 & 1762 & balanced & 9884 & 301 \\
# bacterial & M.tuberculosis (NC\_000962.3) & SRR21864655 & 1762 & balanced & 12576 & 301 \\
# bacterial & E.Coli (NC\_000913.3) & SRR22674487 & 561 & balanced & 16624 & 151 \\
# viral & EBV (GCF\_002402265) & ERR2024408 & 548681 & balanced & 776508 & 300 \\
# viral & SARS-CoV-2 (NC\_045512.2) & ERR10913059 & - & unbalanced & 427828 & 301 \\
# viral & SARS-CoV-2 (NC\_045512.2)  & ERR10913061 & - & unbalanced & 311974 & 301 \\
# \hline
# \end{tabular}
# \input{Tables/sampletable\_table\_desc}\end{table}

# %% [markdown]
# # Runtime Evaluation

# %%
times_orig_manuscript = pd.read_csv("../benchmark_result/classification_timingresults_11Samples_6References.tsv")
times_orig_manuscript=times_orig_manuscript.sort_values(by=["Reference","Sample","Tool"])


# Bind injected Benchmark Data
times_injected = pd.read_csv("../benchmark_result/classification_timingresults_injected_1Samples_1References.tsv")
times_base_model = pd.read_csv("simple_model_results/timings.txt",header=None,names=["Tool","Sample","Reference","User","System","Real"])

times = pd.concat([times_orig_manuscript,times_injected,times_base_model])


times.replace({"Tool":{"Readseeker":"ReadSeeker","SimpleBenchmarkModel":"GB Simple Base Model"}},inplace=True)

times.replace({"Sample":{"demo_coding_vs_intergenomic_seqs":"coding/intergenomic"}},inplace=True) 	

#Optimize Format

caption_runtime = "Real process time comparison of \\textit{ReadSeeker} and \\textit{FragGeneScan}"
times_real = times[["Reference","Sample","Tool","Real"]].copy()



# Fit names for LaTeX Table
shortRefNames = {
    "ecoli":"E. coli",
    "mycobacteriumtubercolosis":"M. tuberculosis",
    "gammaherpes4":"EBV",
    "sars2":"SARS-CoV-2",
    "human":"Human",
    "mouse":"Mouse",
    "human_bm":"Genomic Benchmark (human)"
    
    
}

times_real.replace({"Reference":shortRefNames},inplace=True)


times_real_wide = times_real.pivot(index=["Reference","Sample"],columns='Tool', values='Real')
times_real_wide["Speed Factor (FGS)"] = times_real_wide["ReadSeeker"]/times_real_wide["FragGeneScan"]
times_real_wide["Speed Factor (SBM)"] = times_real_wide["ReadSeeker"]/times_real_wide["GB Simple Base Model"]


times_real_wide_styled = times_real_wide.style.format({"Speed Factor (FGS)": '{:.1f}x',"ReadSeeker": '{:.1f}s',"FragGeneScan": '{:.1f}s', 'GB Simple Base Model': '{:.1f}s','Speed Factor (SBM)': '{:.1f}x'})








print("Table for Paper")
display(times_real_wide_styled)




description = """
The values in the ``FragGeneScan'', ``ReadSeeker'' and ``GB Simple Base Model'' column represents the real process time
in seconds. ``Speed Factor(FGS)'' and ``Speed Factor(SBM)'' are the relative runtimes of \\textit{FragGeneScan} and ``GB Simple Base Model'' compared to \textit{ReadSeeker}. On average \\textit{ReadSeeker} is
around 25 times slower on a \\textit{NVIDIA A40-24Q} with 24GB memory compared to 
\\textit{FragGeneScan} and 8 to 15 times slower on \\textit{Intel(R) Xeon(R) Gold 6130} with 50 Cores. \\textit{ReadSeeker's} evaluation on the ``Genomic Benchmark'' dataset was performed on the same \\textit{Intel(R) Xeon(R) Gold 6130} with 50 Cores, causing outling high speedfactors.
"""
# Out:
# Table for Paper
# <style type="text/css">
# </style>
# <table id="T_fc922">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Tool</th>
#       <th id="T_fc922_level0_col0" class="col_heading level0 col0" >FragGeneScan</th>
#       <th id="T_fc922_level0_col1" class="col_heading level0 col1" >GB Simple Base Model</th>
#       <th id="T_fc922_level0_col2" class="col_heading level0 col2" >ReadSeeker</th>
#       <th id="T_fc922_level0_col3" class="col_heading level0 col3" >Speed Factor (FGS)</th>
#       <th id="T_fc922_level0_col4" class="col_heading level0 col4" >Speed Factor (SBM)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Reference</th>
#       <th class="index_name level1" >Sample</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc922_level0_row0" class="row_heading level0 row0" >E. coli</th>
#       <th id="T_fc922_level1_row0" class="row_heading level1 row0" >SRR22674487</th>
#       <td id="T_fc922_row0_col0" class="data row0 col0" >3.8s</td>
#       <td id="T_fc922_row0_col1" class="data row0 col1" >9.7s</td>
#       <td id="T_fc922_row0_col2" class="data row0 col2" >96.9s</td>
#       <td id="T_fc922_row0_col3" class="data row0 col3" >25.6x</td>
#       <td id="T_fc922_row0_col4" class="data row0 col4" >10.0x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level0_row1" class="row_heading level0 row1" >EBV</th>
#       <th id="T_fc922_level1_row1" class="row_heading level1 row1" >ERR2024408</th>
#       <td id="T_fc922_row1_col0" class="data row1 col0" >148.8s</td>
#       <td id="T_fc922_row1_col1" class="data row1 col1" >218.5s</td>
#       <td id="T_fc922_row1_col2" class="data row1 col2" >3461.2s</td>
#       <td id="T_fc922_row1_col3" class="data row1 col3" >23.3x</td>
#       <td id="T_fc922_row1_col4" class="data row1 col4" >15.8x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level0_row2" class="row_heading level0 row2" >Genomic Benchmark (human)</th>
#       <th id="T_fc922_level1_row2" class="row_heading level1 row2" >coding/intergenomic</th>
#       <td id="T_fc922_row2_col0" class="data row2 col0" >5.4s</td>
#       <td id="T_fc922_row2_col1" class="data row2 col1" >12.3s</td>
#       <td id="T_fc922_row2_col2" class="data row2 col2" >2228.8s</td>
#       <td id="T_fc922_row2_col3" class="data row2 col3" >413.5x</td>
#       <td id="T_fc922_row2_col4" class="data row2 col4" >180.9x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level0_row3" class="row_heading level0 row3" rowspan="3">Human</th>
#       <th id="T_fc922_level1_row3" class="row_heading level1 row3" >ERR10492982</th>
#       <td id="T_fc922_row3_col0" class="data row3 col0" >6.7s</td>
#       <td id="T_fc922_row3_col1" class="data row3 col1" >13.7s</td>
#       <td id="T_fc922_row3_col2" class="data row3 col2" >171.5s</td>
#       <td id="T_fc922_row3_col3" class="data row3 col3" >25.5x</td>
#       <td id="T_fc922_row3_col4" class="data row3 col4" >12.5x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level1_row4" class="row_heading level1 row4" >ERR10493241</th>
#       <td id="T_fc922_row4_col0" class="data row4 col0" >6.8s</td>
#       <td id="T_fc922_row4_col1" class="data row4 col1" >14.1s</td>
#       <td id="T_fc922_row4_col2" class="data row4 col2" >173.3s</td>
#       <td id="T_fc922_row4_col3" class="data row4 col3" >25.4x</td>
#       <td id="T_fc922_row4_col4" class="data row4 col4" >12.3x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level1_row5" class="row_heading level1 row5" >ERR10509672</th>
#       <td id="T_fc922_row5_col0" class="data row5 col0" >5.4s</td>
#       <td id="T_fc922_row5_col1" class="data row5 col1" >12.0s</td>
#       <td id="T_fc922_row5_col2" class="data row5 col2" >135.1s</td>
#       <td id="T_fc922_row5_col3" class="data row5 col3" >25.2x</td>
#       <td id="T_fc922_row5_col4" class="data row5 col4" >11.2x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level0_row6" class="row_heading level0 row6" rowspan="3">M. tuberculosis</th>
#       <th id="T_fc922_level1_row6" class="row_heading level1 row6" >SRR21820122</th>
#       <td id="T_fc922_row6_col0" class="data row6 col0" >2.6s</td>
#       <td id="T_fc922_row6_col1" class="data row6 col1" >8.9s</td>
#       <td id="T_fc922_row6_col2" class="data row6 col2" >67.0s</td>
#       <td id="T_fc922_row6_col3" class="data row6 col3" >26.1x</td>
#       <td id="T_fc922_row6_col4" class="data row6 col4" >7.5x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level1_row7" class="row_heading level1 row7" >SRR21820124</th>
#       <td id="T_fc922_row7_col0" class="data row7 col0" >2.7s</td>
#       <td id="T_fc922_row7_col1" class="data row7 col1" >8.1s</td>
#       <td id="T_fc922_row7_col2" class="data row7 col2" >69.2s</td>
#       <td id="T_fc922_row7_col3" class="data row7 col3" >25.8x</td>
#       <td id="T_fc922_row7_col4" class="data row7 col4" >8.5x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level1_row8" class="row_heading level1 row8" >SRR21864655</th>
#       <td id="T_fc922_row8_col0" class="data row8 col0" >3.1s</td>
#       <td id="T_fc922_row8_col1" class="data row8 col1" >8.9s</td>
#       <td id="T_fc922_row8_col2" class="data row8 col2" >79.8s</td>
#       <td id="T_fc922_row8_col3" class="data row8 col3" >25.8x</td>
#       <td id="T_fc922_row8_col4" class="data row8 col4" >8.9x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level0_row9" class="row_heading level0 row9" >Mouse</th>
#       <th id="T_fc922_level1_row9" class="row_heading level1 row9" >DRR317657</th>
#       <td id="T_fc922_row9_col0" class="data row9 col0" >5.9s</td>
#       <td id="T_fc922_row9_col1" class="data row9 col1" >12.1s</td>
#       <td id="T_fc922_row9_col2" class="data row9 col2" >143.9s</td>
#       <td id="T_fc922_row9_col3" class="data row9 col3" >24.5x</td>
#       <td id="T_fc922_row9_col4" class="data row9 col4" >11.9x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level0_row10" class="row_heading level0 row10" rowspan="2">SARS-CoV-2</th>
#       <th id="T_fc922_level1_row10" class="row_heading level1 row10" >ERR10913059</th>
#       <td id="T_fc922_row10_col0" class="data row10 col0" >86.0s</td>
#       <td id="T_fc922_row10_col1" class="data row10 col1" >156.7s</td>
#       <td id="T_fc922_row10_col2" class="data row10 col2" >2105.0s</td>
#       <td id="T_fc922_row10_col3" class="data row10 col3" >24.5x</td>
#       <td id="T_fc922_row10_col4" class="data row10 col4" >13.4x</td>
#     </tr>
#     <tr>
#       <th id="T_fc922_level1_row11" class="row_heading level1 row11" >ERR10913061</th>
#       <td id="T_fc922_row11_col0" class="data row11 col0" >62.2s</td>
#       <td id="T_fc922_row11_col1" class="data row11 col1" >115.0s</td>
#       <td id="T_fc922_row11_col2" class="data row11 col2" >1531.2s</td>
#       <td id="T_fc922_row11_col3" class="data row11 col3" >24.6x</td>
#       <td id="T_fc922_row11_col4" class="data row11 col4" >13.3x</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Runtime Performance LaTeX

# %%
print(times_real_wide_styled
      .format_index("\\textit{{{}}}", escape="latex", axis=0)
      .set_table_styles([
    {'selector': 'toprule', 'props': ':hline;'},
    {'selector': 'midrule', 'props': ':hline;'},
    {'selector': 'bottomrule', 'props': ':hline;'},], overwrite=True)
      .to_latex(clines="skip-last;data",label="readseeker_runtime", column_format="|l|l|r|r|r|r|r|", caption=caption_runtime)
      .replace("\end{tabular}\n","\end{tabular}\n"+description)
      .replace("\\begin{table}","\\begin{table}[!ht]"))
# Out:
# \begin{table}[!ht]
# \caption{Real process time comparison of \textit{ReadSeeker} and \textit{FragGeneScan}}
# \label{readseeker_runtime}
# \begin{tabular}{|l|l|r|r|r|r|r|}
# \hline
#  & Tool & FragGeneScan & GB Simple Base Model & ReadSeeker & Speed Factor (FGS) & Speed Factor (SBM) \\
# Reference & Sample &  &  &  &  &  \\
# \hline
# \textit{E. coli} & \textit{SRR22674487} & 3.8s & 9.7s & 96.9s & 25.6x & 10.0x \\
# \cline{1-7}
# \textit{EBV} & \textit{ERR2024408} & 148.8s & 218.5s & 3461.2s & 23.3x & 15.8x \\
# \cline{1-7}
# \textit{Genomic Benchmark (human)} & \textit{coding/intergenomic} & 5.4s & 12.3s & 2228.8s & 413.5x & 180.9x \\
# \cline{1-7}
# \multirow[c]{3}{*}{\textit{Human}} & \textit{ERR10492982} & 6.7s & 13.7s & 171.5s & 25.5x & 12.5x \\
#  & \textit{ERR10493241} & 6.8s & 14.1s & 173.3s & 25.4x & 12.3x \\
#  & \textit{ERR10509672} & 5.4s & 12.0s & 135.1s & 25.2x & 11.2x \\
# \cline{1-7}
# \multirow[c]{3}{*}{\textit{M. tuberculosis}} & \textit{SRR21820122} & 2.6s & 8.9s & 67.0s & 26.1x & 7.5x \\
#  & \textit{SRR21820124} & 2.7s & 8.1s & 69.2s & 25.8x & 8.5x \\
#  & \textit{SRR21864655} & 3.1s & 8.9s & 79.8s & 25.8x & 8.9x \\
# \cline{1-7}
# \textit{Mouse} & \textit{DRR317657} & 5.9s & 12.1s & 143.9s & 24.5x & 11.9x \\
# \cline{1-7}
# \multirow[c]{2}{*}{\textit{SARS-CoV-2}} & \textit{ERR10913059} & 86.0s & 156.7s & 2105.0s & 24.5x & 13.4x \\
#  & \textit{ERR10913061} & 62.2s & 115.0s & 1531.2s & 24.6x & 13.3x \\
# \cline{1-7}
# \hline
# \end{tabular}
#
# The values in the ``FragGeneScan'', ``ReadSeeker'' and ``GB Simple Base Model'' column represents the real process time
# in seconds. ``Speed Factor(FGS)'' and ``Speed Factor(SBM)'' are the relative runtimes of \textit{FragGeneScan} and ``GB Simple Base Model'' compared to 	extit{ReadSeeker}. On average \textit{ReadSeeker} is
# around 25 times slower on a \textit{NVIDIA A40-24Q} with 24GB memory compared to
# \textit{FragGeneScan} and 8 to 15 times slower on \textit{Intel(R) Xeon(R) Gold 6130} with 50 Cores. \textit{ReadSeeker's} evaluation on the ``Genomic Benchmark'' dataset was performed on the same \textit{Intel(R) Xeon(R) Gold 6130} with 50 Cores, causing outling high speedfactors.
# \end{table}

# %% [markdown]
# # Time per 1k samples

# %%
relative_times = times_real.copy()
#display(relative_times)

counts = read_count_base_data[["SampleID","# Reads"]].copy()
counts.set_index("SampleID")

rpt = relative_times.merge(counts,left_on='Sample', right_on='SampleID')
rpt["Seconds/1000 Reads"] = rpt["Real"]/rpt["# Reads"]*1000

display(rpt)

rpt_wide=rpt.pivot(index=["Reference","Sample","# Reads"],columns='Tool', values='Seconds/1000 Reads')
rpt_wide_styled = rpt_wide.style.format({"ReadSeeker": '{:.2f}s',"FragGeneScan": '{:.2f}s',"GB Simple Base Model": '{:.2f}s'}).set_table_styles([
    {'selector': 'toprule', 'props': ':hline;'},
    {'selector': 'midrule', 'props': ':hline;'},
    {'selector': 'bottomrule', 'props': ':hline;'},], overwrite=True)
display(rpt_wide_styled)

description = """The table presents a comparison of the real processing time required by \\textit{Readseeker}, \\textit{FragGeneScan} and the ``GB Simple Base Model'' . The column labeled `\\# Reads' indicates the number of reads for each sample. The columns for \\textit{FragGeneScan}, \textit{GB Simple Base Model} and \\textit{Readseeker} display the real processing time measured per 1,000 reads. For the ``Genomic Benchmark (human) dataset'' \textit{ReadSeeker} was evaluated on CPU instead of GPU causing an increased relative runtime."""

print(rpt_wide_styled.to_latex(column_format="|l|l|l|r|r|",clines="skip-last;data",label="subtab_processtime1k", caption="Comparison of the Real Processing Time per 1000 Reads").replace("#","\\#").replace("\end{tabular}\n","\end{tabular}\n"+description))
# Out:
#                     Reference               Sample                  Tool  \
# 0                     E. coli          SRR22674487          FragGeneScan
# 1                     E. coli          SRR22674487            ReadSeeker
# 2                         EBV           ERR2024408          FragGeneScan
# 3                         EBV           ERR2024408            ReadSeeker
# 4                       Human          ERR10492982          FragGeneScan
# 5                       Human          ERR10492982            ReadSeeker
# 6                       Human          ERR10493241          FragGeneScan
# 7                       Human          ERR10493241            ReadSeeker
# 8                       Human          ERR10509672          FragGeneScan
# 9                       Human          ERR10509672            ReadSeeker
# 10                      Mouse            DRR317657          FragGeneScan
# 11                      Mouse            DRR317657            ReadSeeker
# 12            M. tuberculosis          SRR21820122          FragGeneScan
# 13            M. tuberculosis          SRR21820122            ReadSeeker
# 14            M. tuberculosis          SRR21820124          FragGeneScan
# 15            M. tuberculosis          SRR21820124            ReadSeeker
# 16            M. tuberculosis          SRR21864655          FragGeneScan
# 17            M. tuberculosis          SRR21864655            ReadSeeker
# 18                 SARS-CoV-2          ERR10913059          FragGeneScan
# 19                 SARS-CoV-2          ERR10913059            ReadSeeker
# 20                 SARS-CoV-2          ERR10913061          FragGeneScan
# 21                 SARS-CoV-2          ERR10913061            ReadSeeker
# 22  Genomic Benchmark (human)  coding/intergenomic            ReadSeeker
# 23  Genomic Benchmark (human)  coding/intergenomic          FragGeneScan
# 24  Genomic Benchmark (human)  coding/intergenomic  GB Simple Base Model
# 25                      Mouse            DRR317657  GB Simple Base Model
# 26                      Human          ERR10492982  GB Simple Base Model
# 27                      Human          ERR10493241  GB Simple Base Model
# 28                      Human          ERR10509672  GB Simple Base Model
# 29                 SARS-CoV-2          ERR10913059  GB Simple Base Model
# 30                 SARS-CoV-2          ERR10913061  GB Simple Base Model
# 31                        EBV           ERR2024408  GB Simple Base Model
# 32            M. tuberculosis          SRR21820122  GB Simple Base Model
# 33            M. tuberculosis          SRR21820124  GB Simple Base Model
# 34            M. tuberculosis          SRR21864655  GB Simple Base Model
# 35                    E. coli          SRR22674487  GB Simple Base Model
#
#        Real             SampleID  # Reads  Seconds/1000 Reads
# 0      3.79          SRR22674487    16624            0.227984
# 1     96.89          SRR22674487    16624            5.828321
# 2    148.78           ERR2024408   776508            0.191601
# 3   3461.21           ERR2024408   776508            4.457404
# 4      6.72          ERR10492982    31642            0.212376
# 5    171.47          ERR10492982    31642            5.419063
# 6      6.81          ERR10493241    32084            0.212255
# 7    173.31          ERR10493241    32084            5.401758
# 8      5.37          ERR10509672    24262            0.221334
# 9    135.09          ERR10509672    24262            5.567966
# 10     5.87            DRR317657    25926            0.226414
# 11   143.90            DRR317657    25926            5.550413
# 12     2.57          SRR21820122     9718            0.264458
# 13    67.02          SRR21820122     9718            6.896481
# 14     2.68          SRR21820124     9884            0.271145
# 15    69.24          SRR21820124     9884            7.005261
# 16     3.09          SRR21864655    12576            0.245706
# 17    79.81          SRR21864655    12576            6.346215
# 18    85.97          ERR10913059   427828            0.200945
# 19  2105.01          ERR10913059   427828            4.920225
# 20    62.23          ERR10913061   311974            0.199472
# 21  1531.21          ERR10913061   311974            4.908133
# 22  2228.76  coding/intergenomic    25000           89.150400
# 23     5.39  coding/intergenomic    25000            0.215600
# 24    12.32  coding/intergenomic    25000            0.492800
# 25    12.11            DRR317657    25926            0.467099
# 26    13.70          ERR10492982    31642            0.432969
# 27    14.05          ERR10493241    32084            0.437913
# 28    12.03          ERR10509672    24262            0.495837
# 29   156.66          ERR10913059   427828            0.366175
# 30   114.99          ERR10913061   311974            0.368588
# 31   218.53           ERR2024408   776508            0.281427
# 32     8.90          SRR21820122     9718            0.915826
# 33     8.14          SRR21820124     9884            0.823553
# 34     8.93          SRR21864655    12576            0.710083
# 35     9.72          SRR22674487    16624            0.584697
# <style type="text/css">
# #T_0d96d toprule {
#   : hline;
# }
# #T_0d96d midrule {
#   : hline;
# }
# #T_0d96d bottomrule {
#   : hline;
# }
# </style>
# <table id="T_0d96d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Tool</th>
#       <th id="T_0d96d_level0_col0" class="col_heading level0 col0" >FragGeneScan</th>
#       <th id="T_0d96d_level0_col1" class="col_heading level0 col1" >GB Simple Base Model</th>
#       <th id="T_0d96d_level0_col2" class="col_heading level0 col2" >ReadSeeker</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Reference</th>
#       <th class="index_name level1" >Sample</th>
#       <th class="index_name level2" ># Reads</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d96d_level0_row0" class="row_heading level0 row0" >E. coli</th>
#       <th id="T_0d96d_level1_row0" class="row_heading level1 row0" >SRR22674487</th>
#       <th id="T_0d96d_level2_row0" class="row_heading level2 row0" >16624</th>
#       <td id="T_0d96d_row0_col0" class="data row0 col0" >0.23s</td>
#       <td id="T_0d96d_row0_col1" class="data row0 col1" >0.58s</td>
#       <td id="T_0d96d_row0_col2" class="data row0 col2" >5.83s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level0_row1" class="row_heading level0 row1" >EBV</th>
#       <th id="T_0d96d_level1_row1" class="row_heading level1 row1" >ERR2024408</th>
#       <th id="T_0d96d_level2_row1" class="row_heading level2 row1" >776508</th>
#       <td id="T_0d96d_row1_col0" class="data row1 col0" >0.19s</td>
#       <td id="T_0d96d_row1_col1" class="data row1 col1" >0.28s</td>
#       <td id="T_0d96d_row1_col2" class="data row1 col2" >4.46s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level0_row2" class="row_heading level0 row2" >Genomic Benchmark (human)</th>
#       <th id="T_0d96d_level1_row2" class="row_heading level1 row2" >coding/intergenomic</th>
#       <th id="T_0d96d_level2_row2" class="row_heading level2 row2" >25000</th>
#       <td id="T_0d96d_row2_col0" class="data row2 col0" >0.22s</td>
#       <td id="T_0d96d_row2_col1" class="data row2 col1" >0.49s</td>
#       <td id="T_0d96d_row2_col2" class="data row2 col2" >89.15s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level0_row3" class="row_heading level0 row3" rowspan="3">Human</th>
#       <th id="T_0d96d_level1_row3" class="row_heading level1 row3" >ERR10492982</th>
#       <th id="T_0d96d_level2_row3" class="row_heading level2 row3" >31642</th>
#       <td id="T_0d96d_row3_col0" class="data row3 col0" >0.21s</td>
#       <td id="T_0d96d_row3_col1" class="data row3 col1" >0.43s</td>
#       <td id="T_0d96d_row3_col2" class="data row3 col2" >5.42s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level1_row4" class="row_heading level1 row4" >ERR10493241</th>
#       <th id="T_0d96d_level2_row4" class="row_heading level2 row4" >32084</th>
#       <td id="T_0d96d_row4_col0" class="data row4 col0" >0.21s</td>
#       <td id="T_0d96d_row4_col1" class="data row4 col1" >0.44s</td>
#       <td id="T_0d96d_row4_col2" class="data row4 col2" >5.40s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level1_row5" class="row_heading level1 row5" >ERR10509672</th>
#       <th id="T_0d96d_level2_row5" class="row_heading level2 row5" >24262</th>
#       <td id="T_0d96d_row5_col0" class="data row5 col0" >0.22s</td>
#       <td id="T_0d96d_row5_col1" class="data row5 col1" >0.50s</td>
#       <td id="T_0d96d_row5_col2" class="data row5 col2" >5.57s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level0_row6" class="row_heading level0 row6" rowspan="3">M. tuberculosis</th>
#       <th id="T_0d96d_level1_row6" class="row_heading level1 row6" >SRR21820122</th>
#       <th id="T_0d96d_level2_row6" class="row_heading level2 row6" >9718</th>
#       <td id="T_0d96d_row6_col0" class="data row6 col0" >0.26s</td>
#       <td id="T_0d96d_row6_col1" class="data row6 col1" >0.92s</td>
#       <td id="T_0d96d_row6_col2" class="data row6 col2" >6.90s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level1_row7" class="row_heading level1 row7" >SRR21820124</th>
#       <th id="T_0d96d_level2_row7" class="row_heading level2 row7" >9884</th>
#       <td id="T_0d96d_row7_col0" class="data row7 col0" >0.27s</td>
#       <td id="T_0d96d_row7_col1" class="data row7 col1" >0.82s</td>
#       <td id="T_0d96d_row7_col2" class="data row7 col2" >7.01s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level1_row8" class="row_heading level1 row8" >SRR21864655</th>
#       <th id="T_0d96d_level2_row8" class="row_heading level2 row8" >12576</th>
#       <td id="T_0d96d_row8_col0" class="data row8 col0" >0.25s</td>
#       <td id="T_0d96d_row8_col1" class="data row8 col1" >0.71s</td>
#       <td id="T_0d96d_row8_col2" class="data row8 col2" >6.35s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level0_row9" class="row_heading level0 row9" >Mouse</th>
#       <th id="T_0d96d_level1_row9" class="row_heading level1 row9" >DRR317657</th>
#       <th id="T_0d96d_level2_row9" class="row_heading level2 row9" >25926</th>
#       <td id="T_0d96d_row9_col0" class="data row9 col0" >0.23s</td>
#       <td id="T_0d96d_row9_col1" class="data row9 col1" >0.47s</td>
#       <td id="T_0d96d_row9_col2" class="data row9 col2" >5.55s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level0_row10" class="row_heading level0 row10" rowspan="2">SARS-CoV-2</th>
#       <th id="T_0d96d_level1_row10" class="row_heading level1 row10" >ERR10913059</th>
#       <th id="T_0d96d_level2_row10" class="row_heading level2 row10" >427828</th>
#       <td id="T_0d96d_row10_col0" class="data row10 col0" >0.20s</td>
#       <td id="T_0d96d_row10_col1" class="data row10 col1" >0.37s</td>
#       <td id="T_0d96d_row10_col2" class="data row10 col2" >4.92s</td>
#     </tr>
#     <tr>
#       <th id="T_0d96d_level1_row11" class="row_heading level1 row11" >ERR10913061</th>
#       <th id="T_0d96d_level2_row11" class="row_heading level2 row11" >311974</th>
#       <td id="T_0d96d_row11_col0" class="data row11 col0" >0.20s</td>
#       <td id="T_0d96d_row11_col1" class="data row11 col1" >0.37s</td>
#       <td id="T_0d96d_row11_col2" class="data row11 col2" >4.91s</td>
#     </tr>
#   </tbody>
# </table>
# \begin{table}
# \caption{Comparison of the Real Processing Time per 1000 Reads}
# \label{subtab_processtime1k}
# \begin{tabular}{|l|l|l|r|r|}
# \hline
#  &  & Tool & FragGeneScan & GB Simple Base Model & ReadSeeker \\
# Reference & Sample & \# Reads &  &  &  \\
# \hline
# E. coli & SRR22674487 & 16624 & 0.23s & 0.58s & 5.83s \\
# \cline{1-6} \cline{2-6}
# EBV & ERR2024408 & 776508 & 0.19s & 0.28s & 4.46s \\
# \cline{1-6} \cline{2-6}
# Genomic Benchmark (human) & coding/intergenomic & 25000 & 0.22s & 0.49s & 89.15s \\
# \cline{1-6} \cline{2-6}
# \multirow[c]{3}{*}{Human} & ERR10492982 & 31642 & 0.21s & 0.43s & 5.42s \\
# \cline{2-6}
#  & ERR10493241 & 32084 & 0.21s & 0.44s & 5.40s \\
# \cline{2-6}
#  & ERR10509672 & 24262 & 0.22s & 0.50s & 5.57s \\
# \cline{1-6} \cline{2-6}
# \multirow[c]{3}{*}{M. tuberculosis} & SRR21820122 & 9718 & 0.26s & 0.92s & 6.90s \\
# \cline{2-6}
#  & SRR21820124 & 9884 & 0.27s & 0.82s & 7.01s \\
# \cline{2-6}
#  & SRR21864655 & 12576 & 0.25s & 0.71s & 6.35s \\
# \cline{1-6} \cline{2-6}
# Mouse & DRR317657 & 25926 & 0.23s & 0.47s & 5.55s \\
# \cline{1-6} \cline{2-6}
# \multirow[c]{2}{*}{SARS-CoV-2} & ERR10913059 & 427828 & 0.20s & 0.37s & 4.92s \\
# \cline{2-6}
#  & ERR10913061 & 311974 & 0.20s & 0.37s & 4.91s \\
# \cline{1-6} \cline{2-6}
# \hline
# \end{tabular}
# The table presents a comparison of the real processing time required by \textit{Readseeker}, \textit{FragGeneScan} and the ``GB Simple Base Model'' . The column labeled `\# Reads' indicates the number of reads for each sample. The columns for \textit{FragGeneScan}, 	extit{GB Simple Base Model} and \textit{Readseeker} display the real processing time measured per 1,000 reads. For the ``Genomic Benchmark (human) dataset'' 	extit{ReadSeeker} was evaluated on CPU instead of GPU causing an increased relative runtime.\end{table}
